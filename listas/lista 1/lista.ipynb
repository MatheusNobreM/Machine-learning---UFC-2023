# %%
import pandas as pd

# %%
df = pd.read_csv('roubo.csv', encoding="utf-16")
df.head()
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2022        1         1/2022  01/01/2022 00:04:11  01/01/2022 00:30:42
# 1    2021  2528472   2528472/2021  01/01/2022 00:34:31  01/01/2022 00:34:13
# 2    2022        1         1/2022  01/01/2022 00:32:20  01/01/2022 00:41:16
# 3    2022        2         2/2022  01/01/2022 00:41:46  01/01/2022 00:41:29
# 4    2022       11        11/2022  01/01/2022 00:45:00  01/01/2022 00:45:26
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     31/12/2021          22:30          A NOITE      01/01/2022
# 1     31/12/2021          22:20          A NOITE      31/12/2021
# 2     31/12/2021          23:34          A NOITE      01/01/2022
# 3     31/12/2021          21:50          A NOITE      01/01/2022
# 4     31/12/2021          22:30          A NOITE      01/01/2022
#
#         DATAELABORACAO  ... CIDADE_VEICULO DESCR_COR_VEICULO  \
# ...

# %%
df.drop_duplicates()
# Out:
#       ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 0       2022        1         1/2022  01/01/2022 00:04:11
# 1       2021  2528472   2528472/2021  01/01/2022 00:34:31
# 2       2022        1         1/2022  01/01/2022 00:32:20
# 3       2022        2         2/2022  01/01/2022 00:41:46
# 4       2022       11        11/2022  01/01/2022 00:45:00
# ...      ...      ...            ...                  ...
# 6857    2022   233040    233040/2022  31/01/2022 23:16:23
# 6858    2022   233092    233092/2022  31/01/2022 23:23:35
# 6859    2022      733       733/2022  31/01/2022 23:22:55
# 6860    2022      225       225/2022  31/01/2022 23:03:15
# 6861    2022      454       454/2022  31/01/2022 23:51:32
#
#                BO_EMITIDO DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA  \
# 0     01/01/2022 00:30:42     31/12/2021          22:30          A NOITE
# 1     01/01/2022 00:34:13     31/12/2021          22:20          A NOITE
# ...

# %%
print(df.columns.tolist())
# Out:
# ['ANO_BO', 'NUM_BO', 'NUMERO_BOLETIM', 'BO_INICIADO', 'BO_EMITIDO', 'DATAOCORRENCIA', 'HORAOCORRENCIA', 'PERIDOOCORRENCIA', 'DATACOMUNICACAO', 'DATAELABORACAO', 'BO_AUTORIA', 'FLAGRANTE', 'NUMERO_BOLETIM_PRINCIPAL', 'LOGRADOURO', 'NUMERO', 'BAIRRO', 'CIDADE', 'UF', 'LATITUDE', 'LONGITUDE', 'DESCRICAOLOCAL', 'EXAME', 'SOLUCAO', 'DELEGACIA_NOME', 'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA', 'DESDOBRAMENTO', 'STATUS', 'TIPOPESSOA', 'VITIMAFATAL', 'NATURALIDADE', 'NACIONALIDADE', 'SEXO', 'DATANASCIMENTO', 'IDADE', 'ESTADOCIVIL', 'PROFISSAO', 'GRAUINSTRUCAO', 'CORCUTIS', 'NATUREZAVINCULADA', 'TIPOVINCULO', 'RELACIONAMENTO', 'PARENTESCO', 'PLACA_VEICULO', 'UF_VEICULO', 'CIDADE_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO', 'ANO_FABRICACAO', 'ANO_MODELO', 'DESCR_TIPO_VEICULO', 'QUANT_CELULAR', 'MARCA_CELULAR', 'Unnamed: 54', 'Unnamed: 55']

# %%
df = df.loc[df['CIDADE'] == 'S.PAULO']

# %%
print(df.columns.tolist())
# Out:
# ['ANO_BO', 'NUM_BO', 'NUMERO_BOLETIM', 'BO_INICIADO', 'BO_EMITIDO', 'DATAOCORRENCIA', 'HORAOCORRENCIA', 'PERIDOOCORRENCIA', 'DATACOMUNICACAO', 'DATAELABORACAO', 'BO_AUTORIA', 'FLAGRANTE', 'NUMERO_BOLETIM_PRINCIPAL', 'LOGRADOURO', 'NUMERO', 'BAIRRO', 'CIDADE', 'UF', 'LATITUDE', 'LONGITUDE', 'DESCRICAOLOCAL', 'EXAME', 'SOLUCAO', 'DELEGACIA_NOME', 'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA', 'DESDOBRAMENTO', 'STATUS', 'TIPOPESSOA', 'VITIMAFATAL', 'NATURALIDADE', 'NACIONALIDADE', 'SEXO', 'DATANASCIMENTO', 'IDADE', 'ESTADOCIVIL', 'PROFISSAO', 'GRAUINSTRUCAO', 'CORCUTIS', 'NATUREZAVINCULADA', 'TIPOVINCULO', 'RELACIONAMENTO', 'PARENTESCO', 'PLACA_VEICULO', 'UF_VEICULO', 'CIDADE_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO', 'ANO_FABRICACAO', 'ANO_MODELO', 'DESCR_TIPO_VEICULO', 'QUANT_CELULAR', 'MARCA_CELULAR', 'Unnamed: 54', 'Unnamed: 55']

# %%
df.drop(["NUM_BO", "NUMERO_BOLETIM", "NUMERO_BOLETIM_PRINCIPAL", "NUMERO", "UF", "LATITUDE", "LONGITUDE", "DESCRICAOLOCAL","BO_AUTORIA", "EXAME", "QUANT_CELULAR","Unnamed: 54", "Unnamed: 55" ], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    ANO_BO          BO_INICIADO           BO_EMITIDO DATAOCORRENCIA  \
# 0    2022  01/01/2022 00:04:11  01/01/2022 00:30:42     31/12/2021
# 1    2021  01/01/2022 00:34:31  01/01/2022 00:34:13     31/12/2021
# 3    2022  01/01/2022 00:41:46  01/01/2022 00:41:29     31/12/2021
# 5    2022  01/01/2022 00:55:53  01/01/2022 00:55:53     31/12/2021
# 7    2022  01/01/2022 01:02:38  01/01/2022 01:42:32     31/12/2021
#
#   HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0          22:30          A NOITE      01/01/2022  01/01/2022 00:04:11
# 1          22:20          A NOITE      31/12/2021  01/01/2022 00:34:31
# 3          21:50          A NOITE      01/01/2022  01/01/2022 00:41:46
# 5          23:30          A NOITE      01/01/2022  01/01/2022 00:55:53
# 7          23:00          A NOITE      01/01/2022  01/01/2022 01:02:38
#
#   FLAGRANTE                    LOGRADOURO  ... PARENTESCO PLACA_VEICULO  \
# ...

# %%
df = df[df.dropna
# Out:
#       ANO_BO          BO_INICIADO           BO_EMITIDO DATAOCORRENCIA  \
# 0       2022  01/01/2022 00:04:11  01/01/2022 00:30:42     31/12/2021
# 1       2021  01/01/2022 00:34:31  01/01/2022 00:34:13     31/12/2021
# 3       2022  01/01/2022 00:41:46  01/01/2022 00:41:29     31/12/2021
# 5       2022  01/01/2022 00:55:53  01/01/2022 00:55:53     31/12/2021
# 7       2022  01/01/2022 01:02:38  01/01/2022 01:42:32     31/12/2021
# ...      ...                  ...                  ...            ...
# 6836    2022  31/01/2022 21:31:03  31/01/2022 21:31:03     30/01/2022
# 6837    2022  31/01/2022 21:31:03  31/01/2022 21:31:03     30/01/2022
# 6838    2022  31/01/2022 21:31:03  31/01/2022 21:31:03     30/01/2022
# 6839    2022  31/01/2022 21:33:15  31/01/2022 21:33:31     29/01/2022
# 6861    2022  31/01/2022 23:51:32  31/01/2022 23:51:32     31/01/2022
#
#      HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# ...

# %%
df['MARCA_CELULAR']
# Out:
# 0       AUTOMOVEL
# 1       AUTOMOVEL
# 3       AUTOMOVEL
# 5       AUTOMOVEL
# 7       AUTOMOVEL
#           ...
# 6836    MOTOCICLO
# 6837          NaN
# 6838    MOTOCICLO
# 6839    MOTOCICLO
# 6861    MOTOCICLO
# Name: MARCA_CELULAR, Length: 2651, dtype: object
